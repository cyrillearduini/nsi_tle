# %% [markdown]
# # TP : Structures de données linéaires

# %% [markdown]
# ---
# ## 💻 EXERCICE 1 : Créer un type pile
# > Créez en POO la classe `Stack` qui représentera une pile, elle contiendra :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `is_empty()` qui renvoie `True` si la pile est vide et `False` sinon
# >- Une méthode `push(v)` qui ajoute la valeur `v` passée en paramètre au sommet de la pile
# >- Une méthode `pop()` qui renvoie la valeur du sommmet de la pile et le supprime de la pile. Si la pile est vide la methode affichera *"Cannot pop : Empty stack"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la pile du plus ancien au plus récent (le sommet en dernier). La fonction retournera *"Empty stack"* si la pile est vide

# %%
# à compléter

# %%
# Vérifications
p = Stack()         # Création de la pile
p.push(10)          # Empiler 10
p.push(11)          # Empiler 11
p.push(12)          # Empiler 12
p.push(13)          # Empiler 13
v=p.pop()           # Dépiler et renvoyer le 1er élément
print(p)            # Afficher le contenu de la pile : 10 11 12
print(p.is_empty()) # Vérification si la pile est vide : False
for i in range(3):
    p.pop()         # Dépiler 3 éléments
print(p.is_empty()) # Vérifier si la pile est vide : True
print(p.pop())      # Pile vide : message d'erreur et retourne None

# %% [markdown]
# ---
# ## 💻 EXERCICE 2 : Inverser les éléments d'une pile
# > Disposant de la classe `Stack` de l'exercice 1, créez maintenant une fonction `reverse` qui prend en paramètre un objet de la classe `Stack` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > *💡 Utilisez une pile temporaire et une boucle `while`*

# %%
# à compléter

# %%
# Vérifications
p1 = Stack()          # Création de la pile
p1.push(1)            # Empiler 1
p1.push(2)            # Empiler 2
p1.push(3)            # Empiler 3
p1.push(4)            # Empiler 4
print(p1)             # Afficher le contenu de la pile
p2=reverse(p1)        # Inverser les éléments
print(p2)             # Afficher le contenu de la nouvelle pile

# %% [markdown]
# ---
# ## 💻 EXERCICE 3 : Copier une pile
# > Toujours en disposant de la classe `Stack` de l'exercice 1, créez maintenant une fonction `copy` qui prend en paramètre un objet de la classe `Stack` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans le même ordre
# >
# > *💡 Utilisez une pile temporaire*

# %%
# à compléter

# %%
# Vérifications
p3 = Stack()          # Création de la pile
p3.push(1)            # Empiler 1
p3.push(2)            # Empiler 2
p3.push(3)            # Empiler 3
p3.push(4)            # Empiler 4
print(p3)             # Afficher le contenu de la pile
p4=copy(p3)           # Copie les éléments
print(p4)             # Afficher le contenu de la nouvelle pile

# %% [markdown]
# ---
# ## 💻 EXERCICE 4 : Séparer les éléments d'une pile
# > Toujours en disposant de la classe `Stack` de l'exercice 1, créez maintenant une fonction `separate` qui prend en paramètre un objet de la classe `Stack` et renvoie un couple de deux nouveaux éléments de la classe, l'un contenant les éléments pairs et l'autre les éléments impairs.
# > **Attention** : les éléments des deux piles renvoyées doivent être dans l'ordre initial.
# >
# > *💡 Utilisez la fonction `reverse` de l'exercice 2*

# %%
# à compléter

# %%
# Vérifications
p5 = Stack()          # Création de la pile
p5.push(1)            # Empiler 1
p5.push(2)            # Empiler 2
p5.push(3)            # Empiler 3
p5.push(4)            # Empiler 4
print(p5)             # Afficher le contenu de la pile
p6,p7=separate(p5)    # Séparer les éléments
print(p6)             # Afficher le contenu des nouvelles piles
print(p7)

# %% [markdown]
# ---
# ## 💻 EXERCICE 5 : Vérification du parenthésage
# > On dispose d'une chaîne de caractères contenant des parenthèses ouvrantes ou fermantes comme `(()())((())())`. Un parenthésage est considéré correct si en parcourant la chaîne de gauche à droite, à tout moment le nombre de parenthèses ouvertes est supérieur ou égale au nombre de parenthèses déjà fermées. Enfin dans la chaîne complète, il doit y avoir autant de parenthèses ouvrantes que de femantes.
# > - Ecrivez une fonction `test(c)` qui, en utilisant la classe `Stack` de l'exercice 1, parcourt la chaîne passée en paramètre et empile dans une file une valeur (`"("`) lorsque le caractère est "(" et dépile une valeur lorsque le caractère est ")". La fonction affichera le contenu de la pile à la fin de son exécution.

# %%
# à compléter

# %% [markdown]
# > - Vérifions le comportement de ce code, pour chacun des tests, expliquezle comportement de la fonction

# %%
# Vérification
test("(()())")

# %% [markdown]
# > **Comportement :** _à compléter_

# %%
# Vérification
test("())()(")

# %% [markdown]
# > **Comportement :** _à compléter_

# %%
# Vérification
test("(()")

# %% [markdown]
# > **Comportement :** _à compléter_

# %% [markdown]
# > - Ecrivez maintenant une fonction `parenthesage` qui prendra en paramètre une chaîne de caractères et renverra `True` si la chaîne est bien parenthésée et `False` sinon (pas de plantage).

# %%
# à compléter

# %%
# Vérifications
print(parenthesage("(()())"))   # Doit renvoyer True
print(parenthesage("())()("))   # Doit renvoyer False
print(parenthesage("(()"))      # Doit renvoyer False

print(parenthesage("(a+b)^2=a^2+2ab+b^2"))   # Doit renvoyer True
print(parenthesage("((1+1)*(3-4)^2"))        # Doit renvoyer False

# %% [markdown]
# ---
# ## 💻 EXERCICE 6 : Créer un type file
# > Créez en POO la classe `Queue` qui représentera une file, elle contiendra :
# >- Un constructeur qui ne prend aucun paramètre et initialise un attribut `data` contenant un tableau Python (type `list`) vide
# >- Une méthode `is_empty()` qui renvoie `True` si la file est vide et `False` sinon
# >- Une méthode `enq(v)` qui ajoute la valeur `v` passée en paramètre en queue de file
# >- Une méthode `deq()` qui renvoie la valeur de tête de la file et le supprime de la file. Si la file est vide la methode affichera *"Cannot deq : Empty Queue"* et retournera `None`
# >- Une méthode `__repr__` qui permet d'afficher les éléments de la file du plus ancien au plus récent (la tête en dernier). La fonction retournera *"Empty queue"* si la file est vide

# %%
# à compléter

# %%
# Vérifications
f = Queue()         # Création de la file
f.enq(10)           # Enfiler 10
f.enq(11)           # Enfiler 11
f.enq(12)           # Enfiler 12
f.enq(13)           # Enfiler 13
v=f.deq()           # Défiler et renvoyer le 1er élément
print(f)            # Afficher le contenu de la file : 13 12 11
print(f.is_empty()) # Vérification si la file est vide : False
for i in range(3):
    f.deq()         # Défiler 3 éléments
print(f.is_empty()) # Vérifier si la file est vide : True
print(f.deq())      # File vide : message d'erreur et retourne None

# %% [markdown]
# ---
# ## 💻 EXERCICE 7 : Inverser les éléments d'une file
# > Disposant de la classe `Queue` de l'exercice 6, créez maintenant une fonction `reverse_q` qui prend en paramètre un objet de la classe `Queue` et renvoie un nouvel élément de la classe contenant les mêmes éléments dans l'ordre inversé
# >
# > *💡 Utilisez une pile temporaire et une boucle `while`*

# %%
# à compléter

# %%
# Vérifications
f1 = Queue()          # Création de la file
f1.enq(1)             # Emfiler 1
f1.enq(2)             # Emfiler 2
f1.enq(3)             # Emfiler 3
f1.enq(4)             # Emfiler 4
print(f1)             # Afficher le contenu de la file
f2=reverse_q(f1)        # Inverser les éléments
print(f2)             # Afficher le contenu de la nouvelle file

# %% [markdown]
# ---
# ## 💻 EXERCICE 8 : Distribution d'un jeu de cartes
# > Nous souhaitons simuler la distribution d'un jeu de 32 cartes entre 2 joueurs.
# > Le jeu de 32 cartes sera modélisé par une pile contenant les cartes mélangées.
# > Pour la distribution, chaque carte au sommet de la pile est donné tour à tour aux deux joueurs pour constituer deux nouvelles piles. Les deux dernières cartes distribuées sont donc au sommet de chacune des deux piles.
# > Enfin nous simulerons le déroulement d'une partie de bataille : chaque joueur découvre la carte au dessus de son tas.
# > *Note : nous n'écrirons pas le code permettant de tester qui remporte la partie, mais seulement l'affichage des paires de cartes en duel.*
# >
# > - Executez le code suivant pour générer un tableau contenant toutes les cartes du jeu mélangées :

# %%
# Code à exécuter
from random import *

cartes=[i+j for i in ['7','8','9','10','V','D','R','A'] for j in ["♠","♥","♦","♣"]]
shuffle(cartes)

print(cartes)

# %% [markdown]
# > ### Création du jeu de cartes
# > - Créez maintenant un objet de la classe `Stack` créée dans l'exercice 1 nommé `jeu` et ajoutez-y les éléments du tableau `cartes` créé ci-dessus.

# %%
# à compléter

# %%
# Vérification
print(jeu)

# %% [markdown]
# > ### Distribution des cartes à deux joueurs
# > Créez maintenant une fonction `distribue` qui prendra en paramètre une pile (comme notre variable `jeu` ci-dessus) et la distribuera en deux tas, pour cela :
# > - Créez deux objets de la classe `Stack` nommés `tas1` et `tas2`.
# > - Dépilez les cartes de la pile passée en paramètre une à une puis empilez les tour à tour sur les piles `tas1` et `tas2`
# > - La fonction devra renvoyer un tuple contenant les deux tas

# %%
# à compléter

# %%
# Vérification
m1,m2=distribue(jeu)

print(m1)
print(m2)

# %% [markdown]
# > ### Déroulement de la bataille
# > - Ajoutez maintenant une ligne de code qui simulera la découverte des deux cartes du sommet de la pile de chacun des joueurs.
# > - Exemple d'affichage attendu :
# > ```Python
# > A♥  vs  9♠
# > A♣  vs  D♥
# > ...
# > Fin de partie
# ```

# %%
# à compléter

# %% [markdown]
# ---
# ## 💻 EXERCICE 9 : La notation polonaise inversée
#
# > Dans certaines calculatrices, les expressions sont évaluées à l'aide de la [notation polonaise inversée](https://fr.wikipedia.org/wiki/Notation_polonaise_inverse).
# > Cette notation ne nécessite aucune parenthèse ni aucune règle de priorité. Elle place les opérandes avant les opérateurs.
# >
# > ### Exemple
# > En notation polonaise inversée, l'expression `(1+2)*3+4` peut s'écrire `4321+*+`.
# >
# >* Pour calculer cette expression, on lit de gauche à droite jusqu'à trouver un opérateur, ici $+$.
# >* On utilise ensuite les deux derniers opérandes trouvés qui sont $2$  et $1$, puis on effectue l'opération $1+2$.
# >* On remplace les opérandes et l'opérateur utilisés par le résultat de l'opération, ici l'expression devient alors `433*+`.
# >* On utilise l'opérateur suivant sur les deux derniers opérandes présents dans l'expression.Ici on effectue donc $3 \times 3$.
# >* On remplace les opérandes et l'opérateur utilisés par le résultat de l'opération, ici l'expression devient alors `49+`.
# >* On réitère le procédé sur les derniers opérandes, ce qui revient ici à effectuer le calcul $4+9$.
# >* Le résultat est bien $13$ qui est aussi le résutat de $(1+2)*3+4$.
# >
# > ###  Manipulation
# > 1. Quelle notation sera utilisée pour calculer `(3+4)*6+1` ?
# > __Réponse :__ `1634+*+`
# > 2. A quelle expression correspond la notation `4132*+*`?
# > __Réponse :__ `((2*3)+1)*4`
# >
# > ### Implémentation
# >Pour simplifier , on suppose que :
# >- L'on utilise uniquement les opérateurs `+` et `*`.
# >- Les opérandes sont des entiers naturels à un chiffre (entre 0 et 9).
# >- L'expression à évaluer est une chaîne de caractères.
# >
# >La valeur d'une expression en notation polonaise inversée peut être calculée à l'aide d'une pile pour stocker les résultats intermédiaires. Pour cela, on parcourt l'expression de gauche à droite et on effectue les actions suivantes :
# >- Si on voit un nombre , on le place sur la pile.
# >- Si on voit un opérateur, on récupère les deux nombres au sommet de la pile, on leur applique l'opérateur et on replace le résultat au sommet de la pile.
# >- A la fin du processus, il reste exactement un nombre sur la pile, qui est le résultat.
# >
# >Ecrire la fonction `npi(expr)` qui prend en paramètre un chaîne de caractères contenant une expression à évaluer et qui renvoie le résultat de l'évalution de cette expression.
# >
# > *💡 Pour tester si un élément de cette liste de caractères est un nombre, on utilisera la méthode `isdigit()` sur les caractères. Cette méthode renvoie `True` si l'élément est un chiffre et `False` sinon.*

# %%
# à compléter

# %%
# Vérification
exp1='4312+*+'
exp2='1643+*+'
exp3='4132*+*'

print(npi(exp1)) # Doit renvoyer 13
print(npi(exp2)) # Doit renvoyer 43
print(npi(exp3)) # Doit renvoyer 28
