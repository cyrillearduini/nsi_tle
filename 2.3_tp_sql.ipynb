# %% [markdown]
# # Requêtes SQL sur une base de données de Films
# ![cinema.png](attachment:cinema.png)

# %% [markdown]
# ---
# ## Introduction
#
# Maintenant que nous avons les notions élémentaires pour effectuer des requêtes sur une base contenant quelques tables, nous allons travailler sur une vraie base complète et complexe.
# Celle-ci est issue du site du [Cnam](https://deptfod.cnam.fr/bd/tp/) et contient des tables concernant des films, leurs réalisateurs, acteurs, notations par les internautes ...
#
#
# ## Mise en oeuvre
#
# ### Basthon en mode SQL
# > ⚠️ Lors de l'utilisation d'un notebook SQL, assurez vous de l'avoir ouvert avec le bon noyau :
# > - Soit en vérifiant que dans l'url, le noyau a été précisé : `https://notebook.basthon.fr/?kernel=sql&from=https://...`
# > - Soit en sélectionnant le noyau SQL dans le menu de Basthon : `Noyau / Changer de noyau > / SQL`
#
#
# ### Import d'une base de données dans le notebook
# Si vous avez ouvert le fichier pour la première fois via Git, vous n'avez rien à faire, la base de données est chargée dans le notebook.
#
# >⚠️ Si vous réouvrez votre fichier, vous devez importer la base dans le Notebook, pour cela :
# >- Téléchargez le fichier **2.3_FilmCnam.db** disponible sur le dépot Git à coté du TP
# >- Importez le fichier dans le notebook en faisant  `Fichier... / Ouvrir` et le sélectionnant, normalement, le notebook vous informera que le fichier est utilisable depuis SQL.
#
#
# ## Préambule
#
# - Pour manipuler une base de données, il est nécessaire de connaitre sa structure, pour cela vous pouvez afficher la liste de ses tables :

# %%
.tables

# %% [markdown]
# - Pour une visualisation rapide des attributs d'une table :

# %%
SELECT * from Artiste limit 0;

# %% [markdown]
# - Vous pouvez également visualiser toutes les informations de chaque table, notamment la requête qui a permis de la créer, notamment donc ses clés primaires et étrangères en utilisant la requête suivante :

# %%
SELECT * FROM sqlite_master ORDER BY tbl_name, rootpage ;

# %% [markdown]
# ---
# ## Exercices
#
#
# > _💡 Pour chacune des requêtes pensez bien à renommer les colonnes pour que l'affichage des résultats soit le plus soigné possible._

# %% [markdown]
# - **💻 1. Listez distinctement tous les genres triés par ordre alphabétique et renommez la colonne en "Type de film"**

# %% [markdown]
# - **💻 2. Comptez le nombre de films dans chaque genre**

# %% [markdown]
# - **💻 3. Affichez les films sortis entre 1900 et 1945, changez la colonne en "Vieux films" et triez-les par date croissante**

# %% [markdown]
# - **💻 4. Affichez le titre de tous les drames Français sortis après 1970, triez-les par ordre d'année de sortie et nommez la colonne "Drames Français"**

# %% [markdown]
# - **💻 5. Listez les rôles joués par l'acteur Marlon Brando**

# %% [markdown]
# - **💻 6. Qui est le réalisateur de "La Guerre des étoiles" ?**

# %% [markdown]
# - **💻 7. Qui a joué le rôle de Han Solo ?**

# %% [markdown]
# - **💻 8. Affichez l'identifiant, le nom et le nom du réalisateur des films dont le réalisateur joue dans le film**

# %% [markdown]
# - **💻 9. Donnez la date de sortie et le titre des films réalisés par Alfred Hitchcock triés par ordre croissant**

# %% [markdown]
# - **💻 10. Donnez le titre du dernier film d'Alfred Hitchcock dans la base**

# %% [markdown]
# - **💻 11. Quel est l'artiste le plus âgé de la base ? Donnez son nom et son année de naissance**
# _💡 Vous pouvez filtrer les valeurs vides d'une donnée en utilisant `IS NOT NULL`._

# %% [markdown]
# - **💻 12. Quel serait son âge aujourd'hui ?**

# %% [markdown]
# - **💻 13. Citez qui à joué le rôle de "Blondie", dans quel film et à quel âge ?**

# %% [markdown]
# - **💻 14. Quels sont les deux derniers films dans lesquels a joué Michael Caine, quel rôle jouait-il, quel âge avait-il ?**

# %% [markdown]
# - **💻 15. Quel est le nombre total de films dans la base de données ?**

# %% [markdown]
# - **💻 16. Quelle est la moyenne d'âge des artistes dans la base de données ?**
# _💡 Pour arrondir une valeur calculée vous pouvez utiliser le mot clé `ROUND(...)`._

# %% [markdown]
# - **💻 17. Quel est le film le plus récent de la base de données ? Donnez son titre et son année de sortie.**

# %% [markdown]
# - **💻 18. Pour chaque réalisateur : donnez son prénom, son nom et le nombre de films réalisés, liste trié alphabétiquement par nom de famille**

# %% [markdown]
# - **💻 19. Dans combien de films apparaît le rôle de Chewbacca ?**

# %% [markdown]
# - **💻 20. Combien d'acteurs différents ont joué le rôle de Chewbacca ?**

# %% [markdown]
# - **💻 21. Dans quels films David Carradine a-t-il joué le role de Bill ?**

# %% [markdown]
# - **💻 22. Donnez la distribution du film "Sueurs froides"**

# %% [markdown]
# - **💻 23. Donnez le titre des films de Quentin Tarantino dans lesquels il n’a pas joué**
# _💡 Pour rechercher une valeur dans le résultat d'une première requête, vous pouvez utiliser la structure `WHERE ... IN (SELECT ...)`._

# %% [markdown]
# - **💻 24. Affichez le titre des  films sans rôle**

# %% [markdown]
# - **💻 25. Dans quel film peut-on voir la multinationale japonaise "Nakatomi Corporation" ?**

# %% [markdown]
# - **💻 26. Quel âge a le réalisateur du film dans lequel Viggo Mortensen joue-t-il un rôle dans lequel il conduit un pianiste noir ?**
# _💡 Pour rechercher une valeur dans le résultat d'une première requête, vous pouvez utiliser la structure `WHERE ... IN (SELECT ...)`._
